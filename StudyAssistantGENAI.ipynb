# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmiganesh0925/genaiprojects/blob/main/StudyAssistantGENAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
import google.generativeai as genai
from google.colab import userdata

# %%
api_key=userdata.get("GEMINI_API_KEY")

# %%
client = genai.configure(api_key=api_key)

# %%
def study_assistant(user_prompt):
  """
  Sends a prompt to the Gemini model and gets a response.
  """
  model=genai.GenerativeModel('gemini-3-flash-preview')
  response=model.generate_content(user_prompt)
  return response.text

# %%
user_question="Explian Generative AI in simple terms"
output=study_assistant(user_question)
print(output)
# Out:
# At its simplest, **Generative AI** is a type of artificial intelligence that can **create new things.**
#
# Most AI we’ve used in the past was designed to **categorize** or **predict** things (like Spotify recommending a song or your email spotting spam). Generative AI is different because it creates brand-new content that didn't exist before, like poems, images, songs, or computer code.
#
# Here is a breakdown of how it works and why it’s special:
#
# ### 1. How does it work? (The "Pattern Learner")
# Imagine you gave a person a million cookbooks to read. That person wouldn't just memorize the recipes; they would start to understand the *patterns* of cooking. They’d learn that sugar usually goes in desserts and onions usually go in soup.
#
# Generative AI does the same thing with data:
# *   **It learns from a massive library:** It "reads" almost everything on the internet or looks at billions of images.
# ...
